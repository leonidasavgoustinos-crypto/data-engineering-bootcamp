# %%
# %sql
USE CATALOG ai_lab;
USE SCHEMA default;
-- notebook 01
DROP TABLE IF EXISTS bronze_customers;
DROP TABLE IF EXISTS bronze_orders;
DROP TABLE IF EXISTS bronze_products;

DROP TABLE IF EXISTS silver_dim_customers;
DROP TABLE IF EXISTS silver_dim_products;
DROP TABLE IF EXISTS silver_fact_sales;

DROP VIEW IF EXISTS v_serving_sales_performance;
--notebook 02
DROP TABLE IF EXISTS silver_dim_customers_type0;
DROP TABLE IF EXISTS silver_dim_customers_type1;
DROP TABLE IF EXISTS silver_dim_customers_type2;
DROP TABLE IF EXISTS silver_dim_customers_type3;
--notebook 03
DROP TABLE IF EXISTS hub_customer;
DROP TABLE IF EXISTS hub_product;
DROP TABLE IF EXISTS link_order;
DROP TABLE IF EXISTS sat_customer_details;
DROP TABLE IF EXISTS sat_product_details;
DROP TABLE IF EXISTS sat_link_order_details;
